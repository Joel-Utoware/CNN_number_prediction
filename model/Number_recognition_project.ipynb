# %% [markdown]
# # Number recognition project

# %% [markdown]
# The purpose of this project is to use PyTorch to create a Conventional Neural Network (CNN) model to identify the number written in an image. The model would be created using a Modified National Institute of Standards (MNIST) dataset containing images with numbers 0 to 9 written on them. Lastly, to test the model further I will use images I made myself using a Windows application called Paint  to see if the model can correctly identify the numbers given.

# %% [markdown]
# ## Import

# %%
pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: torch==2.9.0 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from -r ../requirements.txt (line 1)) (2.9.0)
# Requirement already satisfied: torchvision==0.24.0 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from -r ../requirements.txt (line 2)) (0.24.0)
# Requirement already satisfied: matplotlib==3.10.0 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from -r ../requirements.txt (line 3)) (3.10.0)
# Requirement already satisfied: Pillow==11.3.0 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from -r ../requirements.txt (line 4)) (11.3.0)
# Requirement already satisfied: mlflow==3.8.1 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from -r ../requirements.txt (line 5)) (3.8.1)
# Requirement already satisfied: pytest==9.0.2 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from -r ../requirements.txt (line 6)) (9.0.2)
# Requirement already satisfied: filelock in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from torch==2.9.0->-r ../requirements.txt (line 1)) (3.12.4)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\joelb\appdata\roaming\python\python311\site-packages (from torch==2.9.0->-r ../requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from torch==2.9.0->-r ../requirements.txt (line 1)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from torch==2.9.0->-r ../requirements.txt (line 1)) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from torch==2.9.0->-r ../requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from torch==2.9.0->-r ../requirements.txt (line 1)) (2025.12.0)
# Requirement already satisfied: numpy in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from torchvision==0.24.0->-r ../requirements.txt (line 2)) (2.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from matplotlib==3.10.0->-r ../requirements.txt (line 3)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from matplotlib==3.10.0->-r ../requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from matplotlib==3.10.0->-r ../requirements.txt (line 3)) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from matplotlib==3.10.0->-r ../requirements.txt (line 3)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\joelb\appdata\roaming\python\python311\site-packages (from matplotlib==3.10.0->-r ../requirements.txt (line 3)) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from matplotlib==3.10.0->-r ../requirements.txt (line 3)) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\joelb\appdata\roaming\python\python311\site-packages (from matplotlib==3.10.0->-r ../requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: mlflow-skinny==3.8.1 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from mlflow==3.8.1->-r ../requirements.txt (line 5)) (3.8.1)
# Requirement already satisfied: mlflow-tracing==3.8.1 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from mlflow==3.8.1->-r ../requirements.txt (line 5)) (3.8.1)
# Requirement already satisfied: Flask-CORS<7 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from mlflow==3.8.1->-r ../requirements.txt (line 5)) (6.0.2)
# Requirement already satisfied: Flask<4 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from mlflow==3.8.1->-r ../requirements.txt (line 5)) (3.1.2)
# Requirement already satisfied: alembic!=1.10.0,<2 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from mlflow==3.8.1->-r ../requirements.txt (line 5)) (1.17.2)
# Requirement already satisfied: cryptography<47,>=43.0.0 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from mlflow==3.8.1->-r ../requirements.txt (line 5)) (46.0.3)
# Requirement already satisfied: docker<8,>=4.0.0 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from mlflow==3.8.1->-r ../requirements.txt (line 5)) (7.1.0)
# Requirement already satisfied: graphene<4 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from mlflow==3.8.1->-r ../requirements.txt (line 5)) (3.4.3)
# Requirement already satisfied: huey<3,>=2.5.0 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from mlflow==3.8.1->-r ../requirements.txt (line 5)) (2.5.5)
# Requirement already satisfied: pandas<3 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from mlflow==3.8.1->-r ../requirements.txt (line 5)) (2.3.3)
# Requirement already satisfied: pyarrow<23,>=4.0.0 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from mlflow==3.8.1->-r ../requirements.txt (line 5)) (22.0.0)
# Requirement already satisfied: scikit-learn<2 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from mlflow==3.8.1->-r ../requirements.txt (line 5)) (1.8.0)
# Requirement already satisfied: scipy<2 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from mlflow==3.8.1->-r ../requirements.txt (line 5)) (1.16.3)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from mlflow==3.8.1->-r ../requirements.txt (line 5)) (2.0.45)
# Requirement already satisfied: waitress<4 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from mlflow==3.8.1->-r ../requirements.txt (line 5)) (3.0.2)
# Requirement already satisfied: colorama>=0.4 in c:\users\joelb\appdata\roaming\python\python311\site-packages (from pytest==9.0.2->-r ../requirements.txt (line 6)) (0.4.6)
# Requirement already satisfied: iniconfig>=1.0.1 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from pytest==9.0.2->-r ../requirements.txt (line 6)) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from pytest==9.0.2->-r ../requirements.txt (line 6)) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in c:\users\joelb\appdata\roaming\python\python311\site-packages (from pytest==9.0.2->-r ../requirements.txt (line 6)) (2.19.2)
# Requirement already satisfied: cachetools<7,>=5.0.0 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from mlflow-skinny==3.8.1->mlflow==3.8.1->-r ../requirements.txt (line 5)) (6.2.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from mlflow-skinny==3.8.1->mlflow==3.8.1->-r ../requirements.txt (line 5)) (8.3.1)
# Requirement already satisfied: cloudpickle<4 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from mlflow-skinny==3.8.1->mlflow==3.8.1->-r ../requirements.txt (line 5)) (3.1.2)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from mlflow-skinny==3.8.1->mlflow==3.8.1->-r ../requirements.txt (line 5)) (0.76.0)
# Requirement already satisfied: fastapi<1 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from mlflow-skinny==3.8.1->mlflow==3.8.1->-r ../requirements.txt (line 5)) (0.128.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from mlflow-skinny==3.8.1->mlflow==3.8.1->-r ../requirements.txt (line 5)) (3.1.45)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from mlflow-skinny==3.8.1->mlflow==3.8.1->-r ../requirements.txt (line 5)) (8.7.1)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from mlflow-skinny==3.8.1->mlflow==3.8.1->-r ../requirements.txt (line 5)) (1.39.1)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from mlflow-skinny==3.8.1->mlflow==3.8.1->-r ../requirements.txt (line 5)) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from mlflow-skinny==3.8.1->mlflow==3.8.1->-r ../requirements.txt (line 5)) (1.39.1)
# Requirement already satisfied: protobuf<7,>=3.12.0 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from mlflow-skinny==3.8.1->mlflow==3.8.1->-r ../requirements.txt (line 5)) (5.29.5)
# Requirement already satisfied: pydantic<3,>=2.0.0 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from mlflow-skinny==3.8.1->mlflow==3.8.1->-r ../requirements.txt (line 5)) (2.12.5)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from mlflow-skinny==3.8.1->mlflow==3.8.1->-r ../requirements.txt (line 5)) (1.2.1)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from mlflow-skinny==3.8.1->mlflow==3.8.1->-r ../requirements.txt (line 5)) (6.0.1)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from mlflow-skinny==3.8.1->mlflow==3.8.1->-r ../requirements.txt (line 5)) (2.32.5)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from mlflow-skinny==3.8.1->mlflow==3.8.1->-r ../requirements.txt (line 5)) (0.5.5)
# Requirement already satisfied: uvicorn<1 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from mlflow-skinny==3.8.1->mlflow==3.8.1->-r ../requirements.txt (line 5)) (0.40.0)
# Requirement already satisfied: Mako in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from alembic!=1.10.0,<2->mlflow==3.8.1->-r ../requirements.txt (line 5)) (1.3.10)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from cryptography<47,>=43.0.0->mlflow==3.8.1->-r ../requirements.txt (line 5)) (2.0.0)
# Requirement already satisfied: google-auth~=2.0 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.8.1->mlflow==3.8.1->-r ../requirements.txt (line 5)) (2.43.0)
# Requirement already satisfied: pywin32>=304 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from docker<8,>=4.0.0->mlflow==3.8.1->-r ../requirements.txt (line 5)) (311)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from docker<8,>=4.0.0->mlflow==3.8.1->-r ../requirements.txt (line 5)) (2.6.1)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from fastapi<1->mlflow-skinny==3.8.1->mlflow==3.8.1->-r ../requirements.txt (line 5)) (0.50.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from fastapi<1->mlflow-skinny==3.8.1->mlflow==3.8.1->-r ../requirements.txt (line 5)) (0.0.4)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from Flask<4->mlflow==3.8.1->-r ../requirements.txt (line 5)) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from Flask<4->mlflow==3.8.1->-r ../requirements.txt (line 5)) (2.2.0)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from Flask<4->mlflow==3.8.1->-r ../requirements.txt (line 5)) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from Flask<4->mlflow==3.8.1->-r ../requirements.txt (line 5)) (3.1.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.8.1->mlflow==3.8.1->-r ../requirements.txt (line 5)) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.8.1->mlflow==3.8.1->-r ../requirements.txt (line 5)) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.8.1->mlflow==3.8.1->-r ../requirements.txt (line 5)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.8.1->mlflow==3.8.1->-r ../requirements.txt (line 5)) (4.9.1)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from graphene<4->mlflow==3.8.1->-r ../requirements.txt (line 5)) (3.2.7)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from graphene<4->mlflow==3.8.1->-r ../requirements.txt (line 5)) (3.2.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.8.1->mlflow==3.8.1->-r ../requirements.txt (line 5)) (3.23.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.8.1->mlflow==3.8.1->-r ../requirements.txt (line 5)) (0.60b1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from pandas<3->mlflow==3.8.1->-r ../requirements.txt (line 5)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from pandas<3->mlflow==3.8.1->-r ../requirements.txt (line 5)) (2025.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.8.1->mlflow==3.8.1->-r ../requirements.txt (line 5)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.8.1->mlflow==3.8.1->-r ../requirements.txt (line 5)) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.8.1->mlflow==3.8.1->-r ../requirements.txt (line 5)) (0.4.2)
# Requirement already satisfied: six>=1.5 in c:\users\joelb\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib==3.10.0->-r ../requirements.txt (line 3)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.8.1->mlflow==3.8.1->-r ../requirements.txt (line 5)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.8.1->mlflow==3.8.1->-r ../requirements.txt (line 5)) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.8.1->mlflow==3.8.1->-r ../requirements.txt (line 5)) (2025.11.12)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.8.1->mlflow==3.8.1->-r ../requirements.txt (line 5)) (0.6.1)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn<2->mlflow==3.8.1->-r ../requirements.txt (line 5)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn<2->mlflow==3.8.1->-r ../requirements.txt (line 5)) (3.6.0)
# Requirement already satisfied: greenlet>=1 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow==3.8.1->-r ../requirements.txt (line 5)) (3.3.0)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.8.1->mlflow==3.8.1->-r ../requirements.txt (line 5)) (4.12.0)
# Requirement already satisfied: h11>=0.8 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from uvicorn<1->mlflow-skinny==3.8.1->mlflow==3.8.1->-r ../requirements.txt (line 5)) (0.16.0)
# Requirement already satisfied: pycparser in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from cffi>=2.0.0->cryptography<47,>=43.0.0->mlflow==3.8.1->-r ../requirements.txt (line 5)) (2.23)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\joelb\appdata\local\programs\python\python311\lib\site-packages (from sympy>=1.13.3->torch==2.9.0->-r ../requirements.txt (line 1)) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from load_model import *

# %% [markdown]
# ## MLflow setup

# %%
mlflow.set_experiment("MNIST_Experiment")

# IMPORTANT: Enable system metrics monitoring
mlflow.config.enable_system_metrics_logging()
mlflow.config.set_system_metrics_sampling_interval(10)

# %% [markdown]
# ## Data preparation

# %% [markdown]
# This section of code obtains the numbered MNIST dataset and preprocesses it so it is ready to be used for the neural network task.

# %%
# create data transformations
transform = transforms.Compose([
    transforms.Resize((28, 28)),
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
])

# download datasets
mnist_train = datasets.MNIST(
    root='/content',
    train=True,
    download=True,
    transform=transform
)

mnist_test = datasets.MNIST(
    root='/content/',
    train=False,
    download=True,
    transform=transform
)

# create dataLoaders
train_loader = DataLoader(mnist_train, batch_size=64, shuffle=True,num_workers=4, pin_memory=True, persistent_workers=True)
test_loader = DataLoader(mnist_test, batch_size=64, shuffle=False,num_workers=4, pin_memory=True)

# %%
len(mnist_train.classes)# classes are numbers 0-9
# Out:
# 10

# %%
# get one batch
images, labels = next(iter(train_loader))
# Out:
# c:\Users\joelb\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\utils\data\dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)

# %%
# view first 5 images in batch
for i in range(0,5):
  plt.imshow(images[i].squeeze(), cmap='gray')
  plt.title(f"Label: {labels[i].item()}")
  plt.axis('off')
  plt.show()

# %%
print(images.shape)
# Out:
# torch.Size([64, 1, 28, 28])

# %% [markdown]
# ## Model creation

# %% [markdown]
# In creating the CNN model, the first thing made is the feature extraction layers. These layers are to extract important features/patterns from the input image.
# Next, it then uses these in the fully connected layers to identify the number in the image.

# %%
# model creation has been moved to seperate load_model.py

# %% [markdown]
# ## Model training

# %% [markdown]
# The model would be trained for up to 10 epochs (how many times it goes through the training data). I am tracking the accuracy as well as the training and validation loss of each epoch. Loss measures how far off the model’s predictions are from the actual target values. Accuracy is the percentage of correct predictions out of total predictions. <br><br>
# The training process will stop if there is no improvement in its accuracy after 3 epochs in a row.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")# use gpu instead of cpu for processing
model = CNN().to(device)# create cnn model

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)# optimizer (Adam) for model parameter updates
scheduler = ReduceLROnPlateau(optimizer, 'max', patience=1)# reduces learning rate if validation accuracy plateaus
criterion = nn.CrossEntropyLoss()# loss function for multi-class classification

# %%
#after running use 'mlflow ui' in terminal on the same directory as file to open results at http://localhost:5000/
n_epochs = 10
epochs_without_improvement = 0
patience = 3 # stop after this many epochs without improvement
# training metrics
best_accuracy = 0.0
cost_list = []# stores training loss per epoch
accuracy_list = []  # stores validation accuracy per epoch
with mlflow.start_run() as run:
    # log training parameters
    mlflow.log_param("learning_rate", 0.001)
    mlflow.log_param("epochs", 10)
    mlflow.log_param("batch_size", 64)

    # create a signature to log with best model (so API know what to expect)
    input_example = next(iter(train_loader))[0][0:1].numpy() 
    prediction_example = model(torch.tensor(input_example).to(device)).detach().cpu().numpy()
    signature = infer_signature(input_example, prediction_example)

    # tags for Searchability
    mlflow.set_tag("model_type", "CNN")
    mlflow.set_tag("dataset", "MNIST")

    for epoch in range(n_epochs):
        model.train() # set model to training mode
        running_loss = 0.0

        #train model
        for x, y in train_loader:# iterate over mini-batches from training data
            x, y = x.to(device, non_blocking=True), y.to(device, non_blocking=True)#move data to gpu/cpu

            optimizer.zero_grad(set_to_none=True)#reset gradients before backward pass

            outputs = model(x)# forward pass: compute model outputs
            loss = criterion(outputs, y)# compute loss between outputs and ground truth

            loss.backward()# backward pass: compute gradients
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)#clip gradients to prevent exploding gradients
            optimizer.step()# update model parameters

            running_loss += loss.item()


        model.eval()# set model to evaluation mode
        correct = 0
        total = 0
        val_loss = 0.0

        # validate model
        with torch.no_grad():#prevent gradient calulation
            for x_test, y_test in test_loader:
                x_test, y_test = x_test.to(device), y_test.to(device)#move validation data to device
                outputs = model(x_test)# forward pass
                loss = criterion(outputs, y_test)
                val_loss += loss.item()

                _, predicted = torch.max(outputs.data, 1)
                total += y_test.size(0)
                correct += (predicted == y_test).sum().item()

        # calculate average training and validation loss for this epoch
        epoch_loss = running_loss / len(train_loader)
        val_loss = val_loss / len(test_loader)

        accuracy = correct / total
        
        scheduler.step(accuracy)
        #save best model
        if accuracy > best_accuracy:
            best_accuracy = accuracy
            epochs_without_improvement = 0
            torch.save(model.state_dict(), 'best_model.pth')
        else:
            epochs_without_improvement += 1
            #end training early if no improvement after 3 epochs in a row
            if epochs_without_improvement >= patience:
                print("Early stopping triggered.")
                break

        cost_list.append(epoch_loss)
        accuracy_list.append(accuracy)
        # Track metrics in MLflow instead of just local lists
        mlflow.log_metric("epoch_loss", epoch_loss, step=epoch)
        mlflow.log_metric("val_loss", val_loss, step=epoch)
        mlflow.log_metric("accuracy", accuracy, step=epoch)
        print(f'Epoch [{epoch+1}/{n_epochs}]')
        print(f'Train Loss: {epoch_loss:.4f} | Val Loss: {val_loss:.4f} | Accuracy: {accuracy:.4f}')
    #log best model
    model.load_state_dict(torch.load('best_model.pth'))       
    mlflow.pytorch.log_model(
        pytorch_model=model,
        artifact_path="mnist_cnn_model",
        registered_model_name="MNIST_Production_Model", 
        signature=signature,
        input_example=input_example
)
# Out:
# 2026/01/01 17:35:50 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2026/01/01 17:35:50 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# Epoch [1/10]
# Train Loss: 0.1176 | Val Loss: 0.0459 | Accuracy: 0.9850
# Epoch [2/10]
# Train Loss: 0.0436 | Val Loss: 0.0313 | Accuracy: 0.9903
# Epoch [3/10]
# Train Loss: 0.0321 | Val Loss: 0.0307 | Accuracy: 0.9907
# Epoch [4/10]
# Train Loss: 0.0248 | Val Loss: 0.0233 | Accuracy: 0.9925
# Epoch [5/10]
# Train Loss: 0.0197 | Val Loss: 0.0291 | Accuracy: 0.9909
# Epoch [6/10]
# Train Loss: 0.0157 | Val Loss: 0.0274 | Accuracy: 0.9925
# Epoch [7/10]
# Train Loss: 0.0060 | Val Loss: 0.0183 | Accuracy: 0.9944
# Epoch [8/10]
# Train Loss: 0.0037 | Val Loss: 0.0172 | Accuracy: 0.9950
# Epoch [9/10]
# Train Loss: 0.0027 | Val Loss: 0.0177 | Accuracy: 0.9951
# 2026/01/01 17:44:13 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# Epoch [10/10]
# Train Loss: 0.0023 | Val Loss: 0.0174 | Accuracy: 0.9954
# Downloading artifacts: 100%|██████████| 8/8 [00:00<00:00, 800.36it/s]
# Registered model 'MNIST_Production_Model' already exists. Creating a new version of this model...
# Created version '2' of model 'MNIST_Production_Model'.
# 2026/01/01 17:44:23 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2026/01/01 17:44:23 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!

# %% [markdown]
# ### Training results

# %% [markdown]
# These results are ideal as it shows that after more epochs the accuracy increases and the cost (epoch loss) decreases. This means that the model should perform well in its task.

# %% [markdown]
# ![metric_results.png](attachment:metric_results.png)

# %% [markdown]
# ## Test Paint images

# %% [markdown]
# To further test the model, I have written used the Paint application to create three images with numbers 1,5 and 7 written on them. In order to apply the model to classify them, they must first be preprocessed to match the format of the MNIST dataset numbers.<br><br>
# In the results, you will see the:
# * The preprocessed image (what the model sees)
# * Then the original image and what the model classified it as

# %%
# load best trained model
best_model =get_best_model()


#new transform so new data matches format of train/test data
transform = transforms.Compose([
    transforms.Resize((28, 28)),
    transforms.Grayscale(),
    transforms.functional.invert,
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
])

def predict_digit(image_path):
    # load and preprocess image
    image = Image.open(image_path)
    image = transform(image).unsqueeze(0)  # add batch dimension
    plt.imshow(image.squeeze(), cmap='gray')#show new preprocessed image
    plt.show()

    # prediction
    with torch.no_grad():
        output = best_model(image)
        _, predicted = torch.max(output, 1)
        probabilities = torch.nn.functional.softmax(output, dim=1)

    return predicted.item(), probabilities.squeeze().tolist()

# Example usage
image_paths = ["../tests/num_1.png", "../tests/num_5.png", "../tests/num_7.png"]

for path in image_paths:
    prediction, probs = predict_digit(path)
    plt.imshow(Image.open(path), cmap='gray')#show original image
    plt.title(f"Predicted: {prediction} | Confidence: {probs[prediction]*100:.1f}%")
    plt.axis('off')
    plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# In conclusion, the project is a success as I have created a CNN model that can accurately classify number images. However, this project overall can be improved further if I were to attempt it again by:
#
# * Adding the model to a webpage where users can draw a number on screen and the program will use the model to attempt to classify the number
# * Training the model to be able to predict numbers outside the range 0-9
